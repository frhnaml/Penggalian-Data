# %%
import pandas as pd


csv_file = 'International Logistic Association Memberships.xlsx - Association ABC memberships.csv'

df_csv = pd.read_csv(csv_file)

print("Nama kolom dalam dataset:")
print(df_csv.columns)

# 2. Menampilkan 7 baris data awal dan informasi dasar dataset
print("\nData dari file CSV:")
print(df_csv.head(7))
print(df_csv.info())

# 3. Menghitung jumlah dan rata-rata iuran
# Menghitung jumlah dan rata-rata iuran jika kolom 'Dues amount' ada
if 'Dues amount' in df_csv.columns:
    df_csv['Dues amount'] = df_csv['Dues amount'].replace(r'[\$,]', '', regex=True).astype(float)
    total_dues = df_csv['Dues amount'].sum()
    avg_dues = df_csv['Dues amount'].mean()
    print(f"\nTotal iuran dari file CSV: {total_dues}")
    print(f"Rata-rata iuran dari file CSV: {avg_dues}")
else:
    print("\nKolom 'Dues amount' tidak ditemukan dalam dataset. Periksa nama kolom yang benar.")
# Out:
# Nama kolom dalam dataset:
# Index(['Member ID', 'Last name', 'First name', 'Address 1', 'Address 2',
#        'Address 3', 'Address 4', 'Address 5', 'Dues amount',
#        'Membership valid through', 'Member type'],
#       dtype='object')
#
# Data dari file CSV:
#    Member ID          Last name  First name              Address 1  \
# 0     100011               Tsao       Danny           27 Wu Tzu St
# 1     100012                Lei     Colleen     88 6th Avenue Teda
# 2     100013               Roth       Nancy       Hoefenstrasse 31
# 3     100014  Meneses Contreras  Karl-Oscar  Poniente 134 Ste. 740
# 4     100015              Nunez      Helmut      Andador Pinos 345
# 5     100016        Fitzpatrick      Dmitry       22 Hemingford Pl
# 6     100017             Andreu        Leya   Nevada de Colima 104
#
#               Address 2 Address 3    Address 4 Address 5 Dues amount  \
# 0           Tamshui 251       NaN       Taiwan       NaN        $200
# ...
